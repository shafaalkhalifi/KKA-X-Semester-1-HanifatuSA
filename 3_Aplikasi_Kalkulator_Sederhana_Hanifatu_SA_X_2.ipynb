# %% [markdown]
# <a href="https://colab.research.google.com/github/shafaalkhalifi/KKA-X-Semester-1-HanifatuSA/blob/main/3_Aplikasi_Kalkulator_Sederhana_Hanifatu_SA_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
panjang = int(input("Masukkan panjang dari persegi panjang (cm): "))
lebar = int(input("Masukkan lebar dari persegi panjang (cm): "))

luas = panjang * lebar

print(f"\nLuas dari persegi panjang yaitu {luas} cm^2")
# Out:
# Masukkan panjang dari persegi panjang (cm): 5
# Masukkan lebar dari persegi panjang (cm): 4
#
# Luas dari persegi panjang yaitu 20 cm^2

# %%
Diameter = int(input("Masukan diameter dari bola (cm):"))
Jari_jari = int(input("Masukan jari-jari dari bola (cm):"))

volume = (4/3) * (22/7) * Jari_jari**3

print(f"\nvolume dari bola yaitu {round(volume)} cm^3")
# Out:
# Masukan diameter dari bola (cm):14
# Masukan jari-jari dari bola (cm):7
#
# volume dari bola yaitu 1437 cm^3
