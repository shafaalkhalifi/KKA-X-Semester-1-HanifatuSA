# %% [markdown]
# <a href="https://colab.research.google.com/github/shafaalkhalifi/KKA-X-Semester-1-HanifatuSA/blob/main/Tipe_Variabel_Hanifatu_SA_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Hanifatu Shafa Al Khalifi
#
# Kelas : X.2
#
# No. absen : 12

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("hanifatushafa.2025@gmail.com")
print("hanifatushafa.2025@gmail.com")
print("hanifatushafa.2025@gmail.com")
# Out:
# hanifatushafa.2025@gmail.com
# hanifatushafa.2025@gmail.com
# hanifatushafa.2025@gmail.com

# %%
email_user = "hanifatushafa.2025@gmail.com"

print(email_user)
print(email_user)
print(email_user)
# Out:
# hanifatushafa.2025@gmail.com
# hanifatushafa.2025@gmail.com
# hanifatushafa.2025@gmail.com

# %%
# Hanya boleh menggunakan huruf, angka, dan underscore
harga telur= 15000

print(harga telur)
# Out:
#   File "/tmp/ipython-input-1337294785.py", line 2
#     harga telur= 15000
#           ^
# SyntaxError: invalid syntax

# %%
hargatelur = 15000
print(hargatelur)
# Out:
# 15000

# %%
# Tidak boleh diawali oleh angka
1_nama_siswa = "Ahmad Dhani"

print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-3063500693.py", line 2
#     1_nama_siswa = "Ahmad Dhani"
#      ^
# SyntaxError: invalid decimal literal

# %%
# Tidak boleh menggunakan kata kunci phyton
if = "Handayani

print(if)
# Out:
#   File "/tmp/ipython-input-4130690333.py", line 2
#     if = "Handayani
#          ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
If = "Handayani"

print(If)
# Out:
# Handayani

# %%
print = "Noor"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2451231669.py in <cell line: 0>()
#       1 print = "Noor"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Noor"
print(Print)
# Out:
# Noor

# %%
# Sensitif terhadap penulisan kapital)
USIA = 17

print(Usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1761080165.py in <cell line: 0>()
#       2 USIA = 17
#       3
# ----> 4 print(Usia)
#
# NameError: name 'Usia' is not defined

# %%
print(USIA)
# Out:
# 17

# %%
_ = "Fazel wardana"

# %%
_ = "Lia wati"

# %%
print(_)
# Out:
# Lia wati

# %% [markdown]
# #Assignment

# %%
#Single_assignment
bb_fazel = 55
bb_dani = 60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
#Multiple_assignment
bb_fazel, bb_dani = 55, 60
print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
bb_fazel, bb dani = 55, 60, 70
print(bb_dani)
print(bb_fazel)
# Out:
#   File "/tmp/ipython-input-298245561.py", line 1
#     bb_fazel, bb dani = 55, 60, 70
#                  ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
nama_siswa_1, nama_siswa_2 = "deni" , "doni"

print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# deni
# doni

# %%
bb_fazel, bb_dani, bb_adli = 55, 60
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-400789157.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani, bb_adli = 55, 60
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#Chain_assignment
bb_hasbi = bb_dani = 60

print(bb_hasbi)
print(bb_dani)
# Out:
# 60
# 60

# %% [markdown]
# #Cara penulisan operator pada phyton

# %%
#Tanpa variabel
print(9+6)
# Out:
# 15

# %%
print("shinta")
# Out:
# shinta

# %%
print("9+6")
# Out:
# 9+6

# %%
#Operand disimpan ke variabel
jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6

print(jumlah_hp_habibi + jumlah_hp_syauqi)
# Out:
# 16

# %%
#Hasil operasi disimpan ke variabel
total_hp = 10 + 6

print(total_hp)
# Out:
# 16

# %%
#Operasi dan hasil operasi disimpan ke variabel
jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6

total_hp = jumlah_hp_habibi + jumlah_hp_syauqi

print(total_hp)
# Out:
# 16

# %% [markdown]
# #Latihan Soal Coding Assignment

# %%
#Single assignment
nama = ("Andi")

print(nama)
# Out:
# Andi

# %%
#Multiple assignment
nama, umur, kelas = ("Budi" , 15, "9A")

print(nama, umur, kelas)
# Out:
# Budi 15 9A

# %%
#Chain assignment
berat_andi = berat_siti = berat_eko = 45.5

print(berat_andi, berat_siti, berat_eko)
# Out:
# 45.5 45.5 45.5

# %% [markdown]
# #Jenis-jenis Tipe Variabel

# %%
a = "Faris"
print(a)
type(a)
# Out:
# Faris
# str

# %%
b = 9.9
print(b)
type(b)
# Out:
# 9.9
# float

# %%
c = 0
print(c)
type(c)
# Out:
# 0
# int

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1844802106.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
f = "False"
print(f)
type(f)
# Out:
# False
# str

# %%
g = 9,2
print(g)
type(g)
# Out:
# (9, 2)
# tuple

# %%
type("rendra")
# Out:
# str

# %%
type(-9.1)
# Out:
# float

# %% [markdown]
# #Mengubah Bentuk Variabel

# %%
a = 5
print(a)
type(a)
# Out:
# 5
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 5.0
# float

# %%
b = bool(2)
print(b)
type(b)
# Out:
# True
# bool

# %% [markdown]
# #Operator Perbandingan

# %%
print(6 >= 6 )
# Out:
# True

# %%
print(8 == 9)
# Out:
# False

# %%
print(8 != 9)
# Out:
# True

# %%
print(8 < 10)
# Out:
# True

# %%
print(8 > 10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(not(5 <= 5))
# Out:
# False

# %%
print(8 > 7 and 6 < 5)
# Out:
# False

# %%
print(7 <= 1 or 2 != 2)
# Out:
# False

# %%
print (not(0 == 1 and 1 != 1))
# Out:
# True

# %%
print(not(5 < 10 or 5 <= 10))
# Out:
# False
